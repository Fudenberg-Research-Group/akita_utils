# %%
import pandas as pd
import numpy as np
import bioframe
from akita_utils.tsv_gen_utils import filter_boundary_ctcfs_from_h5, filter_by_overlap
from akita_utils.format_io import read_rmsk

# %%
rmsk_df = read_rmsk("/project/fudenber_735/genomes/mm10/database/rmsk.txt.gz")

# %%
rmsk_df
# Out:
#          bin  swScore  milliDiv  milliDel  milliIns               chrom  \
# 0        607    12955       105         9        10                chr1
# 1        607     1216       268        31       105                chr1
# 2        607      234       279         0         0                chr1
# 3        607     3685       199        21        14                chr1
# 4        607      376        62        31         0                chr1
# ...      ...      ...       ...       ...       ...                 ...
# 5333734  586     8702        95        80        89  chrna_GL456050_alt
# 5333735  586       44        24         0         0  chrna_GL456050_alt
# 5333736  586     8702        95        80        89  chrna_GL456050_alt
# 5333737  586     5082        56         3         0  chrna_GL456050_alt
# 5333738  586     8702        95        80        89  chrna_GL456050_alt
#
#            start      end   genoLeft strand     repName       repClass  \
# 0        3000000  3002128 -192469843      -     L1_Mus3           LINE
# 1        3003152  3003994 -192467977      -      L1Md_F           LINE
# 2        3003993  3004054 -192467917      -     L1_Mus3           LINE
# 3        3004040  3004206 -192467765      +      L1_Rod           LINE
# 4        3004206  3004270 -192467701      +     (CAAA)n  Simple_repeat
# ...          ...      ...        ...    ...         ...            ...
# 5333734   140098   140367      -1974      +  RMER16-int            LTR
# 5333735   140367   140409      -1932      +       (AG)n  Simple_repeat
# 5333736   140409   140631      -1710      +  RMER16-int            LTR
# 5333737   140631   141216      -1125      -   LTRIS_Mus            LTR
# 5333738   141216   142334         -7      +  RMER16-int            LTR
#
#              repFamily  repStart  repEnd  repLeft  id
# 0                   L1     -3055    3592     1466   1
# 1                   L1     -5902     617        1   2
# 2                   L1     -6034     297      237   3
# 3                   L1      1321    1492    -4355   4
# 4        Simple_repeat         4      69        0   5
# ...                ...       ...     ...      ...  ..
# 5333734           ERVK       411     667    -4739   1
# 5333735  Simple_repeat         1      42        0   1
# 5333736           ERVK       668     930    -4476   1
# 5333737           ERV1         0     587        1   1
# 5333738           ERVK       931    2006    -3400   1
#
# [5333739 rows x 17 columns]

# %%
ctcf_df = bioframe.read_table("/project/fudenber_735/motifs/mm10/jaspar/MA0139.1.tsv.gz", schema='jaspar')

# %%
ctcf_df
# Out:
#         chrom     start       end  name  score  pval strand
# 0       chr10   3103662   3103681  CTCF    814   410      -
# 1       chr10   3108121   3108140  CTCF    859   504      -
# 2       chr10   3119020   3119039  CTCF    801   386      -
# 3       chr10   3124081   3124100  CTCF    807   397      -
# 4       chr10   3127081   3127100  CTCF    810   403      +
# ...       ...       ...       ...   ...    ...   ...    ...
# 825505   chrY  90829177  90829196  CTCF    842   465      +
# 825506   chrY  90839573  90839592  CTCF    804   392      +
# 825507   chrY  90839785  90839804  CTCF    885   565      -
# 825508   chrY  90839787  90839806  CTCF    842   465      +
# 825509   chrY  90844314  90844333  CTCF    822   426      +
#
# [825510 rows x 7 columns]

# %%
# data frame with CTCF sites

sites = filter_boundary_ctcfs_from_h5(
        h5_dirs="/project/fudenber_735/tensorflow_models/akita/v2/analysis/permute_boundaries_motifs_ctcf_mm10_model*/scd.h5",
        score_key="SCD",
        threshold_all_ctcf=0,
    )
# Out:
# annotating each site with boundary-wide scores

# %%
# filtering out sites that overlap more than one CTCF motif

filtered_sites = filter_by_overlap(
                        sites,
                        ctcf_df,
                        exclude_window=60,
                        working_df_cols = ["chrom","start_2","end_2"],
                        filter_df_cols = ["chrom","start","end"],
                        overlap_threshold=1)

# %%
# filtering out sites that overlap repetitive elements

filtered_sites = filter_by_overlap(
                        filtered_sites,
                        rmsk_df,
                        exclude_window=60,
                        working_df_cols = ["chrom","start_2","end_2"],
                        filter_df_cols = ["chrom","start","end"])

# %%
filtered_sites
# Out:
#             SCD       SSD  alt_INS-128  alt_INS-16  alt_INS-256  alt_INS-32  \
# 0     26.125000  5.972656    -0.379639   -0.390381    -0.136719   -0.553223
# 1      0.571289 -0.006458    -0.370850   -0.378662    -0.130859   -0.535645
# 2      0.190796  0.001311    -0.371094   -0.380127    -0.130859   -0.536621
# 3      1.109375  0.053772    -0.370361   -0.376953    -0.130859   -0.534180
# 4      0.532715  0.063232    -0.370605   -0.379395    -0.130737   -0.536621
# ...         ...       ...          ...         ...          ...         ...
# 6549   8.218750  5.265625    -0.233643   -0.316162    -0.243408   -0.406006
# 6550   0.247925 -0.044434    -0.232544   -0.332031    -0.235596   -0.422119
# 6551   0.054901 -0.007572    -0.232300   -0.331787    -0.235596   -0.421875
# 6552   0.186401 -0.007526    -0.231079   -0.332031    -0.235107   -0.421631
# 6553   0.907227  0.070068    -0.496338   -0.325439    -0.278564   -0.481445
#
#       alt_INS-64  boundary_index  boundary_strength_200000  chrom  ...  \
# 0      -0.655273               1                    1.0030   chr1  ...
# 1      -0.637695               1                    1.0030   chr1  ...
# 2      -0.638672               1                    1.0030   chr1  ...
# 3      -0.637695               1                    1.0030   chr1  ...
# 4      -0.638672               1                    1.0030   chr1  ...
# ...          ...             ...                       ...    ...  ...
# 6549   -0.408936            4493                    0.2927  chr19  ...
# 6550   -0.416992            4493                    0.2927  chr19  ...
# 6551   -0.416748            4493                    0.2927  chr19  ...
# 6552   -0.416016            4493                    0.2927  chr19  ...
# 6553   -0.574219            4494                    1.0220  chr19  ...
#
#         INS-32    INS-64   INS-128   INS-256  score_all_ctcf  score_10k  \
# 0     0.017090  0.016602  0.008545  0.005859       28.343750  29.125000
# 1    -0.000488 -0.000977 -0.000244  0.000000       28.343750  29.125000
# 2     0.000488  0.000000  0.000000  0.000000       28.343750  29.125000
# 3    -0.001953 -0.000977 -0.000732  0.000000       28.343750  29.125000
# 4     0.000488  0.000000 -0.000488 -0.000122       28.343750  29.125000
# ...        ...       ...       ...       ...             ...        ...
# 6549 -0.015869 -0.008057  0.001221  0.007812        7.843750  10.265625
# 6550  0.000244  0.000000  0.000122  0.000000        7.843750  10.265625
# 6551  0.000000 -0.000244 -0.000122  0.000000        7.843750  10.265625
# 6552 -0.000244 -0.000977 -0.001343 -0.000488        7.843750  10.265625
# 6553  0.002441  0.001465  0.000977  0.000244        1.742188  22.250000
#
#        start_2     end_2  count  count
# 0      4770055   4770074      1      0
# 1      4770180   4770199      1      0
# 2      4770867   4770886      1      0
# 3      4773435   4773454      1      0
# 4      4775739   4775758      1      0
# ...        ...       ...    ...    ...
# 6549  60152656  60152675      1      0
# 6550  60153312  60153331      1      0
# 6551  60158407  60158426      1      0
# 6552  60158927  60158946      1      0
# 6553  60756843  60756862      1      0
#
# [6554 rows x 34 columns]
