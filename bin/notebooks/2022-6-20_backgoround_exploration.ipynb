# %% [markdown]
# # Background creation and parameter exploration

# %% [markdown]
# ## Explored
# - Creation of a flat background/seq
# - Influencial parameters in creating a flat background/seq

# %% [markdown]
# ## Goal
# - Obtain a standard set of parameters for creating a flat seq.

# %%
# Importing libraries

from basenji import dataset, seqnn, dna_io,stream
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import bioframe 
import pandas as pd
import numpy as np 
import os
import json
from io import StringIO
import seaborn as sns
import akita_utils 
import tensorflow as tf
import pysam
import h5py

# %% [markdown]
# # Getting genomic data

# %%
genome_fasta = '/project/fudenber_735/genomes/mm10/mm10.fa'
genome_open = pysam.Fastafile(genome_fasta)

# %% [markdown]
# # Loading akita model

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = '-1'
print(tf.__version__)

head_i = 1 #mouse
model_num = 1 #which fold to use

base_dir = '/project/fudenber_735/tensorflow_models/akita/v2/models/'
model_dir = base_dir+"/f"+str(model_num)+"c0/train/"
model_file  = model_dir+'/model'+str(head_i)+'_best.h5'

params_file = model_dir+'/params.json'
with open(params_file) as params_open:
    params = json.load(params_open)
    params_model = params['model']
    params_train = params['train']
seq_length = params_model['seq_length']
params_model['verbose'] = False
seqnn_model = seqnn.SeqNN(params_model)
print('built')
seqnn_model.restore(model_file, head_i=head_i)
print('restored')

hic_diags = params_model['diagonal_offset']
try:
    target_crop = params_model['trunk'][-2]['cropping']
except:
    target_crop = params_model['target_crop']
target_length_cropped = int((seq_length//2048 - target_crop*2 - hic_diags)* ((seq_length//2048 - target_crop*2 - hic_diags) +1)/2) 
target_map_size = seq_length//2048  - target_crop*2 
triu_tup = np.triu_indices(target_map_size,2)
target_map_size, target_length_cropped, triu_tup[0].shape
# Out:
# 2.4.1
# 2022-11-22 09:54:25.553871: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# built
# restored
# (512, 130305, (130305,))

# %% [markdown]
# # Fetching chromosome data to explore background creation

# %%
chromsizes = bioframe.read_chromsizes('/project/fudenber_735/tensorflow_models/akita/v2/data/mm10/sequences.bed')
dframe = pd.DataFrame(chromsizes)
dframe['end'] = dframe['length']+ 1310720
dframe = dframe.reset_index()
dframe.rename(columns = {'index' : 'chrom', 'length':'start'}, inplace = True)
df = bioframe.frac_gc(dframe, bioframe.load_fasta('/project/fudenber_735/genomes/mm10/mm10.fa'), return_input=True)

df
# Out:
#      chrom      start        end        GC
# 0     chr1   40415232   41725952  0.407777
# 1     chr1   42708992   44019712  0.424985
# 2     chr1   42053632   43364352  0.424847
# 3     chr1   41725952   43036672  0.411407
# 4     chr1   43036672   44347392  0.417725
# ...    ...        ...        ...       ...
# 6033  chrX   99241984  100552704  0.424162
# 6034  chrX  120532992  121843712  0.367963
# 6035  chrX  139360256  140670976  0.407839
# 6036  chrX  128737280  130048000  0.370827
# 6037  chrX  101535744  102846464  0.430301
#
# [6038 rows x 4 columns]

# %%
# visualizing the gc content distribution

# plt.hist( df['GC'].values, 100);
# np.percentile(df['GC'].dropna().values, np.linspace(1,99,5))

# %% [markdown]
# # Generating a sample for down stream analysis

# %%
super_set = []
error = 0.0001

for gc in np.percentile(df['GC'].dropna().values, np.linspace(1,99,5)):
    for i in range(df.shape[0]):
        if gc-error <= df['GC'].values[i] <= gc+error:
            super_set += [i]
            break

super_set = list(set(super_set)); print(f'Whole distribution: {super_set}')
sample_set = super_set; print(f'Sampled datapoints: {sample_set}')
# Out:
# Whole distribution: [1216, 274, 18, 1076, 600]
# Sampled datapoints: [1216, 274, 18, 1076, 600]

# %% [markdown]
# # Making predictions for the sampled data

# %%
predictions=[]

for ind in set(sample_set):
    chrom, start, end, gc = df.iloc[ind][['chrom','start','end','GC']]
    genome_open = pysam.Fastafile(genome_fasta)
    seq = genome_open.fetch(chrom, start, end).upper()
    seq_1hot = dna_io.dna_1hot(seq)
    predictions.append(seq_1hot)
    
predictions = np.array(predictions)
predictions = seqnn_model.predict(predictions, batch_size=6)
# Out:
# 2022-11-22 09:56:03.672961: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-11-22 09:56:03.673649: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2100000000 Hz

# %% [markdown]
# # Creating flat backroung seqs from sampled data

# %%
# Paramaters for all analysis downstream
max_iters = 10
batch_size = 5
shuffle_k = 8 
ctcf_thresh = 8 
scores_thresh = 5500 
scores_pixelwise_thresh = .05
new_dataframe = df.iloc[[ind for ind in set(sample_set)]]
# ---------------------------------------------------------------

# For comparison further down
shuffle_set = [2,4,8] # shuffling basepairs to sample for comparison
ctcf_thresh_set = [8,15,30] # number of ctcf motifs to sample for comparison

# %%
flat_seqs = akita_utils.create_flat_seqs(seqnn_model=seqnn_model, 
                                        genome_fasta=genome_fasta, 
                                        seq_length=seq_length, 
                                        dataframe=new_dataframe, 
                                        max_iters = max_iters, 
                                        batch_size = batch_size, 
                                        shuffle_k = shuffle_k, 
                                        ctcf_thresh = ctcf_thresh, 
                                        scores_thresh = scores_thresh, 
                                        scores_pixelwise_thresh = scores_pixelwise_thresh )
# Out:
# ind 0 , iter  0 , for chr3 71278592 72589312
# trying: best seq, thresh 6628.0  pixelwise 0.06232
# ind 0 , iter  1 , for chr3 71278592 72589312
# trying: best seq, thresh 7630.0  pixelwise 0.0864
# ind 0 , iter  2 , for chr3 71278592 72589312
# success: best seq, thresh 5308.0  pixelwise 0.04892 time 20.248783111572266
# max iters exceeded, final time 20.248783111572266
# ind 1 , iter  0 , for chr1 158789632 160100352
# trying: best seq, thresh 8910.0  pixelwise 0.0636
# ind 1 , iter  1 , for chr1 158789632 160100352
# trying: best seq, thresh 8036.0  pixelwise 0.0538
# ind 1 , iter  2 , for chr1 158789632 160100352
# trying: best seq, thresh 6150.0  pixelwise 0.05295
# ind 1 , iter  3 , for chr1 158789632 160100352
# trying: best seq, thresh 8696.0  pixelwise 0.1268
# ind 1 , iter  4 , for chr1 158789632 160100352
# trying: best seq, thresh 6710.0  pixelwise 0.05533
# ind 1 , iter  5 , for chr1 158789632 160100352
# trying: best seq, thresh 6740.0  pixelwise 0.05972
# ind 1 , iter  6 , for chr1 158789632 160100352
# trying: best seq, thresh 5864.0  pixelwise 0.052
# ind 1 , iter  7 , for chr1 158789632 160100352
# trying: best seq, thresh 6280.0  pixelwise 0.0961
# ind 1 , iter  8 , for chr1 158789632 160100352
# success: best seq, thresh 5064.0  pixelwise 0.04926 time 57.39528226852417
# max iters exceeded, final time 57.39528226852417
# ind 2 , iter  0 , for chr1 36810752 38121472
# trying: best seq, thresh 8560.0  pixelwise 0.0656
# ind 2 , iter  1 , for chr1 36810752 38121472
# trying: best seq, thresh 18480.0  pixelwise 0.1807
# ind 2 , iter  2 , for chr1 36810752 38121472
# trying: best seq, thresh 7644.0  pixelwise 0.0948
# ind 2 , iter  3 , for chr1 36810752 38121472
# trying: best seq, thresh 8840.0  pixelwise 0.1392
# ind 2 , iter  4 , for chr1 36810752 38121472
# trying: best seq, thresh 9130.0  pixelwise 0.0861
# ind 2 , iter  5 , for chr1 36810752 38121472
# trying: best seq, thresh 9064.0  pixelwise 0.0861
# ind 2 , iter  6 , for chr1 36810752 38121472
# trying: best seq, thresh 9920.0  pixelwise 0.08246
# ind 2 , iter  7 , for chr1 36810752 38121472
# trying: best seq, thresh 9490.0  pixelwise 0.1506
# ind 2 , iter  8 , for chr1 36810752 38121472
# trying: best seq, thresh 10810.0  pixelwise 0.09357
# ind 2 , iter  9 , for chr1 36810752 38121472
# trying: best seq, thresh 8936.0  pixelwise 0.0809
# max iters exceeded, final time 63.79174542427063
# ind 3 , iter  0 , for chr3 81334272 82644992
# success: best seq, thresh 4038.0  pixelwise 0.03613 time 6.455794811248779
# max iters exceeded, final time 6.455794811248779
# ind 4 , iter  0 , for chr2 27127808 28438528
# trying: best seq, thresh 13850.0  pixelwise 0.2725
# ind 4 , iter  1 , for chr2 27127808 28438528
# trying: best seq, thresh 17070.0  pixelwise 0.2069
# ind 4 , iter  2 , for chr2 27127808 28438528
# trying: best seq, thresh 11656.0  pixelwise 0.1631
# ind 4 , iter  3 , for chr2 27127808 28438528
# trying: best seq, thresh 12260.0  pixelwise 0.2084
# ind 4 , iter  4 , for chr2 27127808 28438528
# trying: best seq, thresh 15384.0  pixelwise 0.1617
# ind 4 , iter  5 , for chr2 27127808 28438528
# trying: best seq, thresh 13416.0  pixelwise 0.18
# ind 4 , iter  6 , for chr2 27127808 28438528
# trying: best seq, thresh 14800.0  pixelwise 0.3018
# ind 4 , iter  7 , for chr2 27127808 28438528
# trying: best seq, thresh 15040.0  pixelwise 0.1804
# ind 4 , iter  8 , for chr2 27127808 28438528
# trying: best seq, thresh 11920.0  pixelwise 0.2152
# ind 4 , iter  9 , for chr2 27127808 28438528
# trying: best seq, thresh 16510.0  pixelwise 0.2047
# max iters exceeded, final time 63.95744800567627

# %% [markdown]
# # Visualizing the created flat seqs' contact maps

# %%
fig = plt.figure(figsize=(6* 2 , 6 *  len(sample_set) ), constrained_layout=True)     
spec = fig.add_gridspec(ncols=2, nrows=len(sample_set), hspace=0.1, wspace=0.1)#
           
target_ind = 0
vmin=-2; vmax=2

for i in range(len(sample_set)):
    
    flat_pred = flat_seqs[i][1]
    gc        = flat_seqs[i][-1]
    back_pred = predictions[i]

    mat = akita_utils.from_upper_triu(back_pred[:,target_ind], target_map_size,hic_diags)
    ax1 = fig.add_subplot(spec[i,0])
    im = ax1.matshow(mat, cmap='RdBu_r', vmin=vmin, vmax=vmax)# 
    plt.colorbar(im, fraction=.04, pad = 0.05, ticks=[-2,-1, 0, 1,2])
    plt.title(f'Sequence_{i} GC content_{gc} ** before **')       
           
    mat = akita_utils.from_upper_triu(flat_pred[:,target_ind], target_map_size,hic_diags)
    ax2 = fig.add_subplot(spec[i,1])
    im = ax2.matshow(mat, cmap='RdBu_r', vmin=vmin, vmax=vmax)
    plt.colorbar(im, fraction=.04, pad = 0.05, ticks=[-2,-1, 0, 1,2])       
    plt.title(f'Sequence_{i} GC content_{gc} ** after **')       
        
plt.show()

# %% [markdown]
# # General distribution of scores

# %%
scores_before = {}

for gc in sample_set:
    new_dataframe = df.iloc[[gc]]
    for k in shuffle_set:
        print(gc,k)
        scores_before[gc,k] = akita_utils.custom_calculate_scores(  seqnn_model=seqnn_model, 
                                                                    genome_fasta=genome_fasta, 
                                                                    seq_length=seq_length, 
                                                                    dataframe=new_dataframe, 
                                                                    max_iters = max_iters, 
                                                                    batch_size = batch_size, 
                                                                    shuffle_k = k, 
                                                                    ctcf_thresh = ctcf_thresh, 
                                                                    scores_thresh = scores_thresh,
                                                                    scores_pixelwise_thresh = scores_pixelwise_thresh)
        
# scores_before
# Out:
# 1216 2
# ind 0 , iter  0 ,k  2 , for chr3 71278592 72589312
# ind 0 , iter  1 ,k  2 , for chr3 71278592 72589312
# ind 0 , iter  2 ,k  2 , for chr3 71278592 72589312
# ind 0 , iter  3 ,k  2 , for chr3 71278592 72589312
# ind 0 , iter  4 ,k  2 , for chr3 71278592 72589312
# ind 0 , iter  5 ,k  2 , for chr3 71278592 72589312
# ind 0 , iter  6 ,k  2 , for chr3 71278592 72589312
# ind 0 , iter  7 ,k  2 , for chr3 71278592 72589312
# ind 0 , iter  8 ,k  2 , for chr3 71278592 72589312
# ind 0 , iter  9 ,k  2 , for chr3 71278592 72589312
# max iters exceeded
# 1216 4
# ind 0 , iter  0 ,k  4 , for chr3 71278592 72589312
# ind 0 , iter  1 ,k  4 , for chr3 71278592 72589312
# ind 0 , iter  2 ,k  4 , for chr3 71278592 72589312
# ind 0 , iter  3 ,k  4 , for chr3 71278592 72589312
# ind 0 , iter  4 ,k  4 , for chr3 71278592 72589312
# ind 0 , iter  5 ,k  4 , for chr3 71278592 72589312
# ind 0 , iter  6 ,k  4 , for chr3 71278592 72589312
# ind 0 , iter  7 ,k  4 , for chr3 71278592 72589312
# ind 0 , iter  8 ,k  4 , for chr3 71278592 72589312
# ind 0 , iter  9 ,k  4 , for chr3 71278592 72589312
# max iters exceeded
# 1216 8
# ind 0 , iter  0 ,k  8 , for chr3 71278592 72589312
# ind 0 , iter  1 ,k  8 , for chr3 71278592 72589312
# ind 0 , iter  2 ,k  8 , for chr3 71278592 72589312
# ind 0 , iter  3 ,k  8 , for chr3 71278592 72589312
# ind 0 , iter  4 ,k  8 , for chr3 71278592 72589312
# ind 0 , iter  5 ,k  8 , for chr3 71278592 72589312
# ind 0 , iter  6 ,k  8 , for chr3 71278592 72589312
# ind 0 , iter  7 ,k  8 , for chr3 71278592 72589312
# ind 0 , iter  8 ,k  8 , for chr3 71278592 72589312
# ind 0 , iter  9 ,k  8 , for chr3 71278592 72589312
# max iters exceeded
# 274 2
# ind 0 , iter  0 ,k  2 , for chr1 158789632 160100352
# /home1/kamulege/.conda/envs/basenji-gpu/lib/python3.8/site-packages/numpy/core/_methods.py:48: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# ind 0 , iter  1 ,k  2 , for chr1 158789632 160100352
# ind 0 , iter  2 ,k  2 , for chr1 158789632 160100352
# ind 0 , iter  3 ,k  2 , for chr1 158789632 160100352
# ind 0 , iter  4 ,k  2 , for chr1 158789632 160100352
# ind 0 , iter  5 ,k  2 , for chr1 158789632 160100352
# ind 0 , iter  6 ,k  2 , for chr1 158789632 160100352
# ind 0 , iter  7 ,k  2 , for chr1 158789632 160100352
# ind 0 , iter  8 ,k  2 , for chr1 158789632 160100352
# ind 0 , iter  9 ,k  2 , for chr1 158789632 160100352
# max iters exceeded
# 274 4
# ind 0 , iter  0 ,k  4 , for chr1 158789632 160100352
# ind 0 , iter  1 ,k  4 , for chr1 158789632 160100352
# ind 0 , iter  2 ,k  4 , for chr1 158789632 160100352
# ind 0 , iter  3 ,k  4 , for chr1 158789632 160100352
# ind 0 , iter  4 ,k  4 , for chr1 158789632 160100352
# ind 0 , iter  5 ,k  4 , for chr1 158789632 160100352
# ind 0 , iter  6 ,k  4 , for chr1 158789632 160100352
# ind 0 , iter  7 ,k  4 , for chr1 158789632 160100352
# ind 0 , iter  8 ,k  4 , for chr1 158789632 160100352
# ind 0 , iter  9 ,k  4 , for chr1 158789632 160100352
# max iters exceeded
# 274 8
# ind 0 , iter  0 ,k  8 , for chr1 158789632 160100352
# ind 0 , iter  1 ,k  8 , for chr1 158789632 160100352
# ind 0 , iter  2 ,k  8 , for chr1 158789632 160100352
# ind 0 , iter  3 ,k  8 , for chr1 158789632 160100352
# ind 0 , iter  4 ,k  8 , for chr1 158789632 160100352
# ind 0 , iter  5 ,k  8 , for chr1 158789632 160100352
# ind 0 , iter  6 ,k  8 , for chr1 158789632 160100352
# ind 0 , iter  7 ,k  8 , for chr1 158789632 160100352
# ind 0 , iter  8 ,k  8 , for chr1 158789632 160100352
# ind 0 , iter  9 ,k  8 , for chr1 158789632 160100352
# max iters exceeded
# 18 2
# ind 0 , iter  0 ,k  2 , for chr1 36810752 38121472
# /home1/kamulege/.conda/envs/basenji-gpu/lib/python3.8/site-packages/numpy/core/_methods.py:48: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# ind 0 , iter  1 ,k  2 , for chr1 36810752 38121472
# ind 0 , iter  2 ,k  2 , for chr1 36810752 38121472
# ind 0 , iter  3 ,k  2 , for chr1 36810752 38121472
# ind 0 , iter  4 ,k  2 , for chr1 36810752 38121472
# ind 0 , iter  5 ,k  2 , for chr1 36810752 38121472
# ind 0 , iter  6 ,k  2 , for chr1 36810752 38121472
# ind 0 , iter  7 ,k  2 , for chr1 36810752 38121472
# ind 0 , iter  8 ,k  2 , for chr1 36810752 38121472
# ind 0 , iter  9 ,k  2 , for chr1 36810752 38121472
# max iters exceeded
# 18 4
# ind 0 , iter  0 ,k  4 , for chr1 36810752 38121472
# ind 0 , iter  1 ,k  4 , for chr1 36810752 38121472
# ind 0 , iter  2 ,k  4 , for chr1 36810752 38121472
# ind 0 , iter  3 ,k  4 , for chr1 36810752 38121472
# ind 0 , iter  4 ,k  4 , for chr1 36810752 38121472
# ind 0 , iter  5 ,k  4 , for chr1 36810752 38121472
# ind 0 , iter  6 ,k  4 , for chr1 36810752 38121472
# ind 0 , iter  7 ,k  4 , for chr1 36810752 38121472
# ind 0 , iter  8 ,k  4 , for chr1 36810752 38121472
# ind 0 , iter  9 ,k  4 , for chr1 36810752 38121472
# max iters exceeded
# 18 8
# ind 0 , iter  0 ,k  8 , for chr1 36810752 38121472
# ind 0 , iter  1 ,k  8 , for chr1 36810752 38121472
# ind 0 , iter  2 ,k  8 , for chr1 36810752 38121472
# ind 0 , iter  3 ,k  8 , for chr1 36810752 38121472
# ind 0 , iter  4 ,k  8 , for chr1 36810752 38121472
# ind 0 , iter  5 ,k  8 , for chr1 36810752 38121472
# ind 0 , iter  6 ,k  8 , for chr1 36810752 38121472
# ind 0 , iter  7 ,k  8 , for chr1 36810752 38121472
# ind 0 , iter  8 ,k  8 , for chr1 36810752 38121472
# ind 0 , iter  9 ,k  8 , for chr1 36810752 38121472
# max iters exceeded
# 1076 2
# ind 0 , iter  0 ,k  2 , for chr3 81334272 82644992
# ind 0 , iter  1 ,k  2 , for chr3 81334272 82644992
# ind 0 , iter  2 ,k  2 , for chr3 81334272 82644992
# ind 0 , iter  3 ,k  2 , for chr3 81334272 82644992
# ind 0 , iter  4 ,k  2 , for chr3 81334272 82644992
# ind 0 , iter  5 ,k  2 , for chr3 81334272 82644992
# ind 0 , iter  6 ,k  2 , for chr3 81334272 82644992
# ind 0 , iter  7 ,k  2 , for chr3 81334272 82644992
# ind 0 , iter  8 ,k  2 , for chr3 81334272 82644992
# ind 0 , iter  9 ,k  2 , for chr3 81334272 82644992
# max iters exceeded
# 1076 4
# ind 0 , iter  0 ,k  4 , for chr3 81334272 82644992
# ind 0 , iter  1 ,k  4 , for chr3 81334272 82644992
# ind 0 , iter  2 ,k  4 , for chr3 81334272 82644992
# ind 0 , iter  3 ,k  4 , for chr3 81334272 82644992
# ind 0 , iter  4 ,k  4 , for chr3 81334272 82644992
# ind 0 , iter  5 ,k  4 , for chr3 81334272 82644992
# ind 0 , iter  6 ,k  4 , for chr3 81334272 82644992
# ind 0 , iter  7 ,k  4 , for chr3 81334272 82644992
# ind 0 , iter  8 ,k  4 , for chr3 81334272 82644992
# ind 0 , iter  9 ,k  4 , for chr3 81334272 82644992
# max iters exceeded
# 1076 8
# ind 0 , iter  0 ,k  8 , for chr3 81334272 82644992
# ind 0 , iter  1 ,k  8 , for chr3 81334272 82644992
# ind 0 , iter  2 ,k  8 , for chr3 81334272 82644992
# ind 0 , iter  3 ,k  8 , for chr3 81334272 82644992
# ind 0 , iter  4 ,k  8 , for chr3 81334272 82644992
# ind 0 , iter  5 ,k  8 , for chr3 81334272 82644992
# ind 0 , iter  6 ,k  8 , for chr3 81334272 82644992
# ind 0 , iter  7 ,k  8 , for chr3 81334272 82644992
# ind 0 , iter  8 ,k  8 , for chr3 81334272 82644992
# ind 0 , iter  9 ,k  8 , for chr3 81334272 82644992
# max iters exceeded
# 600 2
# ind 0 , iter  0 ,k  2 , for chr2 27127808 28438528
# ind 0 , iter  1 ,k  2 , for chr2 27127808 28438528
# ind 0 , iter  2 ,k  2 , for chr2 27127808 28438528
# ind 0 , iter  3 ,k  2 , for chr2 27127808 28438528
# ind 0 , iter  4 ,k  2 , for chr2 27127808 28438528
# ind 0 , iter  5 ,k  2 , for chr2 27127808 28438528
# ind 0 , iter  6 ,k  2 , for chr2 27127808 28438528
# ind 0 , iter  7 ,k  2 , for chr2 27127808 28438528
# ind 0 , iter  8 ,k  2 , for chr2 27127808 28438528
# ind 0 , iter  9 ,k  2 , for chr2 27127808 28438528
# max iters exceeded
# 600 4
# ind 0 , iter  0 ,k  4 , for chr2 27127808 28438528
# ind 0 , iter  1 ,k  4 , for chr2 27127808 28438528
# ind 0 , iter  2 ,k  4 , for chr2 27127808 28438528
# ind 0 , iter  3 ,k  4 , for chr2 27127808 28438528
# /home1/kamulege/.conda/envs/basenji-gpu/lib/python3.8/site-packages/numpy/core/_methods.py:48: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# ind 0 , iter  4 ,k  4 , for chr2 27127808 28438528
# ind 0 , iter  5 ,k  4 , for chr2 27127808 28438528
# ind 0 , iter  6 ,k  4 , for chr2 27127808 28438528
# ind 0 , iter  7 ,k  4 , for chr2 27127808 28438528
# ind 0 , iter  8 ,k  4 , for chr2 27127808 28438528
# ind 0 , iter  9 ,k  4 , for chr2 27127808 28438528
# max iters exceeded
# 600 8
# ind 0 , iter  0 ,k  8 , for chr2 27127808 28438528
# ind 0 , iter  1 ,k  8 , for chr2 27127808 28438528
# ind 0 , iter  2 ,k  8 , for chr2 27127808 28438528
# ind 0 , iter  3 ,k  8 , for chr2 27127808 28438528
# ind 0 , iter  4 ,k  8 , for chr2 27127808 28438528
# ind 0 , iter  5 ,k  8 , for chr2 27127808 28438528
# ind 0 , iter  6 ,k  8 , for chr2 27127808 28438528
# ind 0 , iter  7 ,k  8 , for chr2 27127808 28438528
# ind 0 , iter  8 ,k  8 , for chr2 27127808 28438528
# ind 0 , iter  9 ,k  8 , for chr2 27127808 28438528
# max iters exceeded

# %% [markdown]
# # Visualing the scores' distribution for the created flat seqs

# %%
fig = plt.figure(figsize=(6* len(shuffle_set) , 6 *  len(sample_set) ), constrained_layout=True)     
spec = fig.add_gridspec(ncols=len(shuffle_set), nrows=len(sample_set), hspace=0.1, wspace=0.1)
           
for ind in sample_set:
    chrom, start, end, gc = df.iloc[ind][['chrom','start','end','GC']]
    for k in shuffle_set:
        ax1 = fig.add_subplot(spec[sample_set.index(ind),shuffle_set.index(k)])
        
        temp_scores_before = []
        for i in scores_before[ind,k]:
            temp_scores_before =+ i
        
        kde_df_before = pd.DataFrame(temp_scores_before, columns=["score"])
        sns.kdeplot(data=kde_df_before, x="score", bw_adjust=.2, fill=True)
        
        plt.title(f'GC_{gc} k_{k} score distributions')
        plt.legend()

plt.show()
plt.close()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# /home1/kamulege/.conda/envs/basenji-gpu/lib/python3.8/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# /home1/kamulege/.conda/envs/basenji-gpu/lib/python3.8/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# # Some observations
#
# With a threshold of 6000;
#
# As the gc content lowers, scores below threshold are obtained in k=8, some low scores can be obtained in the k=4,2. For really low gc content, more low scores can be obtained for k=4.
#
# This implies k=8 is the best option over a wide range of gc content distribution and thus will be used futher on.

# %%
shuffle_set = [4,8]

# %% [markdown]
# # Now we focus on how to maskout some CTCF motifs to lower the structure in our maps (this is discussed in detail in the mutation method notebook)

# %% [markdown]
# # Some observations
#
# There are three ways to go about this;
# - just randomly shuffle the whole seq
# - scan for CTCF and randomly shuffle the motifs
# - scan for CTCF and manually shuffle the motifs
#
# ## RESULTS
# In terms of scores, all these cases tend to produce the same distribution.
# In terms of time to a successfull iteration, there are slight differences as observed  in the mutation method notebook. This could be very much dependent on the GC content of the seq under investigation.

# %% [markdown]
# # Now we try different thresholds to the minimum CTCF motifs in a seq above which we start the shuffling process (ctcf_thresh)

# %%
ctcf_thresh_after = {}

for gc in sample_set:
    new_dataframe = df.iloc[[gc]]
    for score in ctcf_thresh_set:
        print(gc,score)
        ctcf_thresh_after[gc,score] = akita_utils.custom_calculate_scores(seqnn_model = seqnn_model, 
                                                            genome_fasta = genome_fasta, 
                                                            seq_length = seq_length, 
                                                            dataframe = new_dataframe, 
                                                            max_iters = max_iters, 
                                                            batch_size = batch_size, 
                                                            shuffle_k = 8, 
                                                            ctcf_thresh = score,#ctcf_thresh, 
                                                            scores_thresh = scores_thresh,#score, 
                                                            scores_pixelwise_thresh = scores_pixelwise_thresh,
                                                            success_scores = 1,                
                                                            masking = True)
# Out:
# 1216 8
# ind 0 , iter  0 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 6150.0  pixelwise 0.04266 ***
# ind 0 , iter  1 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 7440.0  pixelwise 0.046 ***
# ind 0 , iter  2 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 7388.0  pixelwise 0.04663 ***
# ind 0 , iter  3 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 5256.0  pixelwise 0.03247 ***
# ind 0 , iter  4 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 5780.0  pixelwise 0.0381 ***
# ind 0 , iter  5 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 6628.0  pixelwise 0.04758 ***
# ind 0 , iter  6 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 5724.0  pixelwise 0.04544 ***
# ind 0 , iter  7 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 5940.0  pixelwise 0.04507 ***
# ind 0 , iter  8 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 6620.0  pixelwise 0.04428 ***
# ind 0 , iter  9 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 6870.0  pixelwise 0.04282 ***
# max iters exceeded
# 1216 15
# ind 0 , iter  0 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 13720.0  pixelwise 0.152
# ind 0 , iter  1 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 6172.0  pixelwise 0.0407 ***
# ind 0 , iter  2 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 3808.0  pixelwise 0.05695 ***
# ind 0 , iter  3 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 8330.0  pixelwise 0.04367 ***
# ind 0 , iter  4 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 7844.0  pixelwise 0.05322
# ind 0 , iter  5 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 7308.0  pixelwise 0.0461 ***
# ind 0 , iter  6 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 8010.0  pixelwise 0.07043
# ind 0 , iter  7 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 6188.0  pixelwise 0.0543
# ind 0 , iter  8 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 5360.0  pixelwise 0.1145 ***
# ind 0 , iter  9 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 7150.0  pixelwise 0.06015
# max iters exceeded
# 1216 30
# ind 0 , iter  0 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 8600.0  pixelwise 0.07855
# ind 0 , iter  1 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 6830.0  pixelwise 0.05872
# ind 0 , iter  2 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 6740.0  pixelwise 0.077
# ind 0 , iter  3 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 6376.0  pixelwise 0.0779
# ind 0 , iter  4 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 6850.0  pixelwise 0.06506
# ind 0 , iter  5 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 10220.0  pixelwise 0.08215
# ind 0 , iter  6 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 5960.0  pixelwise 0.0484 ***
# ind 0 , iter  7 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 7984.0  pixelwise 0.052
# ind 0 , iter  8 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 6504.0  pixelwise 0.04306 ***
# ind 0 , iter  9 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 8450.0  pixelwise 0.06287
# max iters exceeded
# 274 8
# ind 0 , iter  0 ,k  8 , for chr1 158789632 160100352
# *** success: best seq, thresh 6356.0  pixelwise 0.0414 ***
# ind 0 , iter  1 ,k  8 , for chr1 158789632 160100352
# *** success: best seq, thresh 4636.0  pixelwise 0.0371 ***
# ind 0 , iter  2 ,k  8 , for chr1 158789632 160100352
# *** success: best seq, thresh 4520.0  pixelwise 0.04306 ***
# ind 0 , iter  3 ,k  8 , for chr1 158789632 160100352
# *** success: best seq, thresh 5320.0  pixelwise 0.04257 ***
# ind 0 , iter  4 ,k  8 , for chr1 158789632 160100352
# *** success: best seq, thresh 5216.0  pixelwise 0.0332 ***
# ind 0 , iter  5 ,k  8 , for chr1 158789632 160100352
# *** success: best seq, thresh 6600.0  pixelwise 0.04404 ***
# ind 0 , iter  6 ,k  8 , for chr1 158789632 160100352
# *** success: best seq, thresh 4092.0  pixelwise 0.03748 ***
# ind 0 , iter  7 ,k  8 , for chr1 158789632 160100352
# *** success: best seq, thresh 4770.0  pixelwise 0.0295 ***
# ind 0 , iter  8 ,k  8 , for chr1 158789632 160100352
# *** success: best seq, thresh 4990.0  pixelwise 0.03467 ***
# ind 0 , iter  9 ,k  8 , for chr1 158789632 160100352
# *** success: best seq, thresh 5330.0  pixelwise 0.03693 ***
# max iters exceeded
# 274 15
# ind 0 , iter  0 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 7188.0  pixelwise 0.05228
# ind 0 , iter  1 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 6890.0  pixelwise 0.07733
# ind 0 , iter  2 ,k  8 , for chr1 158789632 160100352
# *** success: best seq, thresh 7610.0  pixelwise 0.0407 ***
# ind 0 , iter  3 ,k  8 , for chr1 158789632 160100352
# *** success: best seq, thresh 4930.0  pixelwise 0.04388 ***
# ind 0 , iter  4 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 7296.0  pixelwise 0.06104
# ind 0 , iter  5 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 7460.0  pixelwise 0.0776
# ind 0 , iter  6 ,k  8 , for chr1 158789632 160100352
# *** success: best seq, thresh 5904.0  pixelwise 0.04266 ***
# ind 0 , iter  7 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 5744.0  pixelwise 0.08527
# ind 0 , iter  8 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 7890.0  pixelwise 0.07886
# ind 0 , iter  9 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 5870.0  pixelwise 0.0703
# max iters exceeded
# 274 30
# ind 0 , iter  0 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 8350.0  pixelwise 0.07556
# ind 0 , iter  1 ,k  8 , for chr1 158789632 160100352
# *** success: best seq, thresh 8240.0  pixelwise 0.04544 ***
# ind 0 , iter  2 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 7364.0  pixelwise 0.1268
# ind 0 , iter  3 ,k  8 , for chr1 158789632 160100352
# *** success: best seq, thresh 3882.0  pixelwise 0.0625 ***
# ind 0 , iter  4 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 8660.0  pixelwise 0.0652
# ind 0 , iter  5 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 7056.0  pixelwise 0.05316
# ind 0 , iter  6 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 5964.0  pixelwise 0.07306
# ind 0 , iter  7 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 5964.0  pixelwise 0.10944
# ind 0 , iter  8 ,k  8 , for chr1 158789632 160100352
# *** success: best seq, thresh 6236.0  pixelwise 0.04013 ***
# ind 0 , iter  9 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 11640.0  pixelwise 0.1109
# max iters exceeded
# 18 8
# ind 0 , iter  0 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 8960.0  pixelwise 0.0583
# ind 0 , iter  1 ,k  8 , for chr1 36810752 38121472
# *** success: best seq, thresh 8690.0  pixelwise 0.04996 ***
# ind 0 , iter  2 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 8550.0  pixelwise 0.0619
# ind 0 , iter  3 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 8530.0  pixelwise 0.0646
# ind 0 , iter  4 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 8016.0  pixelwise 0.05566
# ind 0 , iter  5 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 8530.0  pixelwise 0.06635
# ind 0 , iter  6 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 6950.0  pixelwise 0.05737
# ind 0 , iter  7 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 9096.0  pixelwise 0.058
# ind 0 , iter  8 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 8390.0  pixelwise 0.05295
# ind 0 , iter  9 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 8710.0  pixelwise 0.05942
# max iters exceeded
# 18 15
# ind 0 , iter  0 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 7504.0  pixelwise 0.0805
# ind 0 , iter  1 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 8410.0  pixelwise 0.07477
# ind 0 , iter  2 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 10616.0  pixelwise 0.086
# ind 0 , iter  3 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 9624.0  pixelwise 0.1348
# ind 0 , iter  4 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 10560.0  pixelwise 0.0877
# ind 0 , iter  5 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 7140.0  pixelwise 0.0741
# ind 0 , iter  6 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 7036.0  pixelwise 0.0673
# ind 0 , iter  7 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 7060.0  pixelwise 0.1069
# ind 0 , iter  8 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 6364.0  pixelwise 0.0741
# ind 0 , iter  9 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 10250.0  pixelwise 0.10846
# max iters exceeded
# 18 30
# ind 0 , iter  0 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 9920.0  pixelwise 0.114
# ind 0 , iter  1 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 10230.0  pixelwise 0.1417
# ind 0 , iter  2 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 8904.0  pixelwise 0.1589
# ind 0 , iter  3 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 8140.0  pixelwise 0.068
# ind 0 , iter  4 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 11144.0  pixelwise 0.075
# ind 0 , iter  5 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 9220.0  pixelwise 0.10657
# ind 0 , iter  6 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 12220.0  pixelwise 0.1421
# ind 0 , iter  7 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 6270.0  pixelwise 0.09827
# ind 0 , iter  8 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 10650.0  pixelwise 0.0801
# ind 0 , iter  9 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 6560.0  pixelwise 0.0816
# max iters exceeded
# 1076 8
# ind 0 , iter  0 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 4252.0  pixelwise 0.0358 ***
# ind 0 , iter  1 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 5796.0  pixelwise 0.03326 ***
# ind 0 , iter  2 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 4776.0  pixelwise 0.03433 ***
# ind 0 , iter  3 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 6280.0  pixelwise 0.03674 ***
# ind 0 , iter  4 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 6240.0  pixelwise 0.03738 ***
# ind 0 , iter  5 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 4060.0  pixelwise 0.0384 ***
# ind 0 , iter  6 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 5800.0  pixelwise 0.0317 ***
# ind 0 , iter  7 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 5924.0  pixelwise 0.03766 ***
# ind 0 , iter  8 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 4630.0  pixelwise 0.04315 ***
# ind 0 , iter  9 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 6020.0  pixelwise 0.03888 ***
# max iters exceeded
# 1076 15
# ind 0 , iter  0 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 5364.0  pixelwise 0.0806 ***
# ind 0 , iter  1 ,k  8 , for chr3 81334272 82644992
# trying: best seq, thresh 8830.0  pixelwise 0.05972
# ind 0 , iter  2 ,k  8 , for chr3 81334272 82644992
# trying: best seq, thresh 7500.0  pixelwise 0.06104
# ind 0 , iter  3 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 5836.0  pixelwise 0.04373 ***
# ind 0 , iter  4 ,k  8 , for chr3 81334272 82644992
# trying: best seq, thresh 7744.0  pixelwise 0.05643
# ind 0 , iter  5 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 7036.0  pixelwise 0.04904 ***
# ind 0 , iter  6 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 4516.0  pixelwise 0.0753 ***
# ind 0 , iter  7 ,k  8 , for chr3 81334272 82644992
# trying: best seq, thresh 7852.0  pixelwise 0.07056
# ind 0 , iter  8 ,k  8 , for chr3 81334272 82644992
# trying: best seq, thresh 11064.0  pixelwise 0.1127
# ind 0 , iter  9 ,k  8 , for chr3 81334272 82644992
# trying: best seq, thresh 6812.0  pixelwise 0.08496
# max iters exceeded
# 1076 30
# ind 0 , iter  0 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 4920.0  pixelwise 0.0583 ***
# ind 0 , iter  1 ,k  8 , for chr3 81334272 82644992
# trying: best seq, thresh 6812.0  pixelwise 0.07654
# ind 0 , iter  2 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 5484.0  pixelwise 0.0546 ***
# ind 0 , iter  3 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 5040.0  pixelwise 0.04642 ***
# ind 0 , iter  4 ,k  8 , for chr3 81334272 82644992
# trying: best seq, thresh 9820.0  pixelwise 0.1481
# ind 0 , iter  5 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 5860.0  pixelwise 0.0425 ***
# ind 0 , iter  6 ,k  8 , for chr3 81334272 82644992
# trying: best seq, thresh 10536.0  pixelwise 0.07855
# ind 0 , iter  7 ,k  8 , for chr3 81334272 82644992
# trying: best seq, thresh 8370.0  pixelwise 0.08484
# ind 0 , iter  8 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 5852.0  pixelwise 0.0407 ***
# ind 0 , iter  9 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 6596.0  pixelwise 0.04575 ***
# max iters exceeded
# 600 8
# ind 0 , iter  0 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 19250.0  pixelwise 0.1522
# ind 0 , iter  1 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 16030.0  pixelwise 0.1542
# ind 0 , iter  2 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 14730.0  pixelwise 0.1605
# ind 0 , iter  3 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 17010.0  pixelwise 0.1854
# ind 0 , iter  4 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 15860.0  pixelwise 0.1648
# ind 0 , iter  5 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 14620.0  pixelwise 0.1617
# ind 0 , iter  6 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 15140.0  pixelwise 0.194
# ind 0 , iter  7 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 18030.0  pixelwise 0.2084
# ind 0 , iter  8 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 15780.0  pixelwise 0.1609
# ind 0 , iter  9 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 17100.0  pixelwise 0.165
# max iters exceeded
# 600 15
# ind 0 , iter  0 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 19380.0  pixelwise 0.2241
# ind 0 , iter  1 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 14380.0  pixelwise 0.2025
# ind 0 , iter  2 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 15750.0  pixelwise 0.2932
# ind 0 , iter  3 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 9210.0  pixelwise 0.1434
# ind 0 , iter  4 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 28460.0  pixelwise 0.4487
# ind 0 , iter  5 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 24700.0  pixelwise 0.204
# ind 0 , iter  6 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 11096.0  pixelwise 0.2644
# ind 0 , iter  7 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 11860.0  pixelwise 0.2004
# ind 0 , iter  8 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 15780.0  pixelwise 0.1644
# ind 0 , iter  9 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 23680.0  pixelwise 0.305
# max iters exceeded
# 600 30
# ind 0 , iter  0 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 14584.0  pixelwise 0.1595
# ind 0 , iter  1 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 17660.0  pixelwise 0.2023
# ind 0 , iter  2 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 14550.0  pixelwise 0.1251
# ind 0 , iter  3 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 12104.0  pixelwise 0.139
# ind 0 , iter  4 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 18740.0  pixelwise 0.2607
# ind 0 , iter  5 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 14400.0  pixelwise 0.2483
# ind 0 , iter  6 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 11390.0  pixelwise 0.1777
# ind 0 , iter  7 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 13480.0  pixelwise 0.2142
# ind 0 , iter  8 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 17920.0  pixelwise 0.1876
# ind 0 , iter  9 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 14820.0  pixelwise 0.1857
# max iters exceeded

# %% [markdown]
# # Visualing the scores' distribution for the created seqs

# %%
fig1 = plt.figure(figsize=(6* len(ctcf_thresh_set) , 6 *  len(sample_set) ), constrained_layout=True)     
spec1 = fig1.add_gridspec(ncols=len(ctcf_thresh_set), nrows=len(sample_set), hspace=0.1, wspace=0.1)#
           
for ind in sample_set:
    chrom, start, end, gc = df.iloc[ind][['chrom','start','end','GC']]
    for score in ctcf_thresh_set:
        ax1 = fig1.add_subplot(spec1[sample_set.index(ind),ctcf_thresh_set.index(score)])
        
        temp_ctcf_thresh_after = []
        for i in ctcf_thresh_after[ind,score]:
            temp_ctcf_thresh_after =+ i
        
        kde_df_after = pd.DataFrame(temp_ctcf_thresh_after, columns=["score"])
        sns.kdeplot(data=kde_df_after, x="score", bw_adjust=.1, fill=True)
        ax1.legend()        
        plt.title(f'GC_{gc} scores_thresh_{score}')

plt.show()
plt.close()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# # Some observations
#
#
# For high gc content and low threshold, there is no success.  As the gc content lowers, some success can be obtained in higher thresholds. For really low gc content, more success can be obtained for lower thresholds.
#
# This implies that to create a background seq, you need a reasonably low gc content and threshold.

# %% [markdown]
# # Now we focus on effect of masking to basepairs shuffled.

# %%
ctcf_shuffle_after = {}

for gc in sample_set:
    new_dataframe = df.iloc[[gc]]
    for k in shuffle_set:
        print(gc,k)
        ctcf_shuffle_after[gc,k] = akita_utils.custom_calculate_scores(seqnn_model = seqnn_model, 
                                                                    genome_fasta = genome_fasta, 
                                                                    seq_length = seq_length, 
                                                                    dataframe = new_dataframe, 
                                                                    max_iters = max_iters, 
                                                                    batch_size = batch_size, 
                                                                    shuffle_k = k, 
                                                                    ctcf_thresh = ctcf_thresh, 
                                                                    scores_thresh = scores_thresh, 
                                                                    scores_pixelwise_thresh = scores_pixelwise_thresh,
                                                                    success_scores = 1,
                                                                    masking = False)
# Out:
# 1216 4
# ind 0 , iter  0 ,k  4 , for chr3 71278592 72589312
# trying: best seq, thresh 9990.0  pixelwise 0.1067
# ind 0 , iter  1 ,k  4 , for chr3 71278592 72589312
# trying: best seq, thresh 8104.0  pixelwise 0.11255
# ind 0 , iter  2 ,k  4 , for chr3 71278592 72589312
# trying: best seq, thresh 8440.0  pixelwise 0.101
# ind 0 , iter  3 ,k  4 , for chr3 71278592 72589312
# trying: best seq, thresh 10180.0  pixelwise 0.1234
# ind 0 , iter  4 ,k  4 , for chr3 71278592 72589312
# trying: best seq, thresh 9400.0  pixelwise 0.1376
# ind 0 , iter  5 ,k  4 , for chr3 71278592 72589312
# trying: best seq, thresh 8760.0  pixelwise 0.1653
# ind 0 , iter  6 ,k  4 , for chr3 71278592 72589312
# trying: best seq, thresh 8420.0  pixelwise 0.1215
# ind 0 , iter  7 ,k  4 , for chr3 71278592 72589312
# trying: best seq, thresh 9416.0  pixelwise 0.104
# ind 0 , iter  8 ,k  4 , for chr3 71278592 72589312
# trying: best seq, thresh 7820.0  pixelwise 0.135
# ind 0 , iter  9 ,k  4 , for chr3 71278592 72589312
# trying: best seq, thresh 11040.0  pixelwise 0.1248
# max iters exceeded
# 1216 8
# ind 0 , iter  0 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 6416.0  pixelwise 0.0555
# ind 0 , iter  1 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 7804.0  pixelwise 0.04678 ***
# ind 0 , iter  2 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 8310.0  pixelwise 0.05356
# ind 0 , iter  3 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 6948.0  pixelwise 0.04044 ***
# ind 0 , iter  4 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 5876.0  pixelwise 0.0525
# ind 0 , iter  5 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 7988.0  pixelwise 0.08624
# ind 0 , iter  6 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 6456.0  pixelwise 0.0787
# ind 0 , iter  7 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 5148.0  pixelwise 0.0673 ***
# ind 0 , iter  8 ,k  8 , for chr3 71278592 72589312
# *** success: best seq, thresh 4828.0  pixelwise 0.04147 ***
# ind 0 , iter  9 ,k  8 , for chr3 71278592 72589312
# trying: best seq, thresh 6980.0  pixelwise 0.05148
# max iters exceeded
# 274 4
# ind 0 , iter  0 ,k  4 , for chr1 158789632 160100352
# trying: best seq, thresh 16640.0  pixelwise 0.1929
# ind 0 , iter  1 ,k  4 , for chr1 158789632 160100352
# trying: best seq, thresh 14940.0  pixelwise 0.1815
# ind 0 , iter  2 ,k  4 , for chr1 158789632 160100352
# trying: best seq, thresh 18260.0  pixelwise 0.2131
# ind 0 , iter  3 ,k  4 , for chr1 158789632 160100352
# trying: best seq, thresh 18860.0  pixelwise 0.1968
# ind 0 , iter  4 ,k  4 , for chr1 158789632 160100352
# trying: best seq, thresh 13960.0  pixelwise 0.155
# ind 0 , iter  5 ,k  4 , for chr1 158789632 160100352
# trying: best seq, thresh 14620.0  pixelwise 0.1543
# ind 0 , iter  6 ,k  4 , for chr1 158789632 160100352
# trying: best seq, thresh 12810.0  pixelwise 0.1682
# ind 0 , iter  7 ,k  4 , for chr1 158789632 160100352
# trying: best seq, thresh 12584.0  pixelwise 0.12427
# ind 0 , iter  8 ,k  4 , for chr1 158789632 160100352
# trying: best seq, thresh 14050.0  pixelwise 0.1622
# ind 0 , iter  9 ,k  4 , for chr1 158789632 160100352
# trying: best seq, thresh 16500.0  pixelwise 0.2379
# max iters exceeded
# 274 8
# ind 0 , iter  0 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 6770.0  pixelwise 0.05234
# ind 0 , iter  1 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 5668.0  pixelwise 0.0534
# ind 0 , iter  2 ,k  8 , for chr1 158789632 160100352
# *** success: best seq, thresh 7440.0  pixelwise 0.04257 ***
# ind 0 , iter  3 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 6540.0  pixelwise 0.06976
# ind 0 , iter  4 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 7884.0  pixelwise 0.05472
# ind 0 , iter  5 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 8340.0  pixelwise 0.0712
# ind 0 , iter  6 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 7320.0  pixelwise 0.0715
# ind 0 , iter  7 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 9064.0  pixelwise 0.0917
# ind 0 , iter  8 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 6372.0  pixelwise 0.0667
# ind 0 , iter  9 ,k  8 , for chr1 158789632 160100352
# trying: best seq, thresh 6530.0  pixelwise 0.08246
# max iters exceeded
# 18 4
# ind 0 , iter  0 ,k  4 , for chr1 36810752 38121472
# trying: best seq, thresh 21660.0  pixelwise 0.278
# ind 0 , iter  1 ,k  4 , for chr1 36810752 38121472
# trying: best seq, thresh 16540.0  pixelwise 0.2705
# ind 0 , iter  2 ,k  4 , for chr1 36810752 38121472
# trying: best seq, thresh 22540.0  pixelwise 0.2325
# ind 0 , iter  3 ,k  4 , for chr1 36810752 38121472
# trying: best seq, thresh 17650.0  pixelwise 0.2937
# ind 0 , iter  4 ,k  4 , for chr1 36810752 38121472
# trying: best seq, thresh 15070.0  pixelwise 0.2236
# ind 0 , iter  5 ,k  4 , for chr1 36810752 38121472
# trying: best seq, thresh 18260.0  pixelwise 0.255
# ind 0 , iter  6 ,k  4 , for chr1 36810752 38121472
# trying: best seq, thresh 19950.0  pixelwise 0.3071
# ind 0 , iter  7 ,k  4 , for chr1 36810752 38121472
# trying: best seq, thresh 15640.0  pixelwise 0.3462
# ind 0 , iter  8 ,k  4 , for chr1 36810752 38121472
# trying: best seq, thresh 16380.0  pixelwise 0.211
# ind 0 , iter  9 ,k  4 , for chr1 36810752 38121472
# trying: best seq, thresh 20370.0  pixelwise 0.232
# max iters exceeded
# 18 8
# ind 0 , iter  0 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 8890.0  pixelwise 0.0972
# ind 0 , iter  1 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 9496.0  pixelwise 0.0899
# ind 0 , iter  2 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 7420.0  pixelwise 0.09064
# ind 0 , iter  3 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 6404.0  pixelwise 0.0939
# ind 0 , iter  4 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 7450.0  pixelwise 0.1029
# ind 0 , iter  5 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 5620.0  pixelwise 0.08453
# ind 0 , iter  6 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 11030.0  pixelwise 0.1392
# ind 0 , iter  7 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 7428.0  pixelwise 0.0675
# ind 0 , iter  8 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 8730.0  pixelwise 0.09906
# ind 0 , iter  9 ,k  8 , for chr1 36810752 38121472
# trying: best seq, thresh 6852.0  pixelwise 0.0781
# max iters exceeded
# 1076 4
# ind 0 , iter  0 ,k  4 , for chr3 81334272 82644992
# trying: best seq, thresh 15624.0  pixelwise 0.102
# ind 0 , iter  1 ,k  4 , for chr3 81334272 82644992
# trying: best seq, thresh 17180.0  pixelwise 0.1287
# ind 0 , iter  2 ,k  4 , for chr3 81334272 82644992
# trying: best seq, thresh 19420.0  pixelwise 0.1865
# ind 0 , iter  3 ,k  4 , for chr3 81334272 82644992
# trying: best seq, thresh 17810.0  pixelwise 0.166
# ind 0 , iter  4 ,k  4 , for chr3 81334272 82644992
# trying: best seq, thresh 16560.0  pixelwise 0.117
# ind 0 , iter  5 ,k  4 , for chr3 81334272 82644992
# trying: best seq, thresh 16800.0  pixelwise 0.1755
# ind 0 , iter  6 ,k  4 , for chr3 81334272 82644992
# trying: best seq, thresh 18530.0  pixelwise 0.1383
# ind 0 , iter  7 ,k  4 , for chr3 81334272 82644992
# trying: best seq, thresh 14536.0  pixelwise 0.1309
# ind 0 , iter  8 ,k  4 , for chr3 81334272 82644992
# trying: best seq, thresh 17730.0  pixelwise 0.1004
# ind 0 , iter  9 ,k  4 , for chr3 81334272 82644992
# trying: best seq, thresh 15416.0  pixelwise 0.1564
# max iters exceeded
# 1076 8
# ind 0 , iter  0 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 6148.0  pixelwise 0.03796 ***
# ind 0 , iter  1 ,k  8 , for chr3 81334272 82644992
# trying: best seq, thresh 6744.0  pixelwise 0.06207
# ind 0 , iter  2 ,k  8 , for chr3 81334272 82644992
# trying: best seq, thresh 6890.0  pixelwise 0.0655
# ind 0 , iter  3 ,k  8 , for chr3 81334272 82644992
# trying: best seq, thresh 6068.0  pixelwise 0.0831
# ind 0 , iter  4 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 6460.0  pixelwise 0.04492 ***
# ind 0 , iter  5 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 6790.0  pixelwise 0.0477 ***
# ind 0 , iter  6 ,k  8 , for chr3 81334272 82644992
# trying: best seq, thresh 6570.0  pixelwise 0.05997
# ind 0 , iter  7 ,k  8 , for chr3 81334272 82644992
# *** success: best seq, thresh 7588.0  pixelwise 0.04904 ***
# ind 0 , iter  8 ,k  8 , for chr3 81334272 82644992
# trying: best seq, thresh 7616.0  pixelwise 0.0667
# ind 0 , iter  9 ,k  8 , for chr3 81334272 82644992
# trying: best seq, thresh 7496.0  pixelwise 0.0733
# max iters exceeded
# 600 4
# ind 0 , iter  0 ,k  4 , for chr2 27127808 28438528
# trying: best seq, thresh 34050.0  pixelwise 0.562
# ind 0 , iter  1 ,k  4 , for chr2 27127808 28438528
# trying: best seq, thresh 32800.0  pixelwise 0.6226
# ind 0 , iter  2 ,k  4 , for chr2 27127808 28438528
# trying: best seq, thresh 32510.0  pixelwise 0.57
# ind 0 , iter  3 ,k  4 , for chr2 27127808 28438528
# trying: best seq, thresh 38750.0  pixelwise 0.646
# ind 0 , iter  4 ,k  4 , for chr2 27127808 28438528
# trying: best seq, thresh 37540.0  pixelwise 0.621
# ind 0 , iter  5 ,k  4 , for chr2 27127808 28438528
# trying: best seq, thresh 36400.0  pixelwise 0.638
# ind 0 , iter  6 ,k  4 , for chr2 27127808 28438528
# trying: best seq, thresh 21170.0  pixelwise 0.474
# ind 0 , iter  7 ,k  4 , for chr2 27127808 28438528
# trying: best seq, thresh 38180.0  pixelwise 0.657
# ind 0 , iter  8 ,k  4 , for chr2 27127808 28438528
# trying: best seq, thresh 28880.0  pixelwise 0.5664
# ind 0 , iter  9 ,k  4 , for chr2 27127808 28438528
# trying: best seq, thresh 28800.0  pixelwise 0.537
# max iters exceeded
# 600 8
# ind 0 , iter  0 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 17420.0  pixelwise 0.29
# ind 0 , iter  1 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 15270.0  pixelwise 0.2396
# ind 0 , iter  2 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 20450.0  pixelwise 0.2832
# ind 0 , iter  3 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 17340.0  pixelwise 0.2468
# ind 0 , iter  4 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 13360.0  pixelwise 0.191
# ind 0 , iter  5 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 16780.0  pixelwise 0.2756
# ind 0 , iter  6 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 19980.0  pixelwise 0.277
# ind 0 , iter  7 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 16190.0  pixelwise 0.1621
# ind 0 , iter  8 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 11496.0  pixelwise 0.1539
# ind 0 , iter  9 ,k  8 , for chr2 27127808 28438528
# trying: best seq, thresh 17820.0  pixelwise 0.3962
# max iters exceeded

# %% [markdown]
# # Visualizing the resultant score distributions.

# %%
fig = plt.figure(figsize=(6* len(shuffle_set) , 6 *  len(sample_set) ), constrained_layout=True)     
spec = fig.add_gridspec(ncols=len(shuffle_set), nrows=len(sample_set), hspace=0.1, wspace=0.1)
           
for ind in sample_set:
    chrom, start, end, gc = df.iloc[ind][['chrom','start','end','GC']]
    for k in shuffle_set:
        ax1 = fig.add_subplot(spec[sample_set.index(ind),shuffle_set.index(k)])
        # plt.hist(scores_after[gc,k],5)
        
        temp_scores_shuffle_after = []
        for i in ctcf_shuffle_after[ind,k]: #scores_shuffle_after
            temp_scores_shuffle_after =+ i
            
        temp_scores_before = []
        for i in scores_before[ind,k]:
            temp_scores_before =+ i
        
        kde_df_after = pd.DataFrame(temp_scores_shuffle_after, columns=["score"])
        kde_df_before = pd.DataFrame(temp_scores_before, columns=["score"])
        sns.kdeplot(data=kde_df_after, x="score", bw_adjust=.1, label='after',fill=True)
        sns.kdeplot(data=kde_df_before, x="score", bw_adjust=.1, label='before',fill=True)#
        ax1.legend()
        plt.title(f'GC_{gc} k_{k} before and after masking')
plt.show()
plt.close()

# %% [markdown]
# # Final observations
#
# The first parameter for focus when desighing a background seq is the gc content of the initial seq.
# Seq with lower gc are preffeerd
#
# The second parameter is the shuffling basepairs, 8 are prefferd
#
# Third is whether masking is necessary. According to preliminary results, the difference in the timing seems to be minimal but further analysis is underway.
