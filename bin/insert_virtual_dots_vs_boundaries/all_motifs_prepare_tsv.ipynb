# %%
import h5py
import pandas as pd
import numpy as np
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns

# %%
from akita_utils.tsv_gen_utils import add_orientation, add_const_flank_and_diff_spacer, add_background

# %% [markdown]
# ## goal
# modify tsv with all single spans ctcfs that I used for insertion vs disruption experiment

# %%
all_ctcf_path = "./filtered_base_mouse_ctcf.tsv"

# %%
df = pd.read_csv(all_ctcf_path, sep="\t")

# %%
df
# Out:
#       boundary_index  chrom  boundary_end  index  num_ctcf               span  \
# 0                  0   chr1       4410000      0         2    4403267-4403286
# 1                  1   chr1       4780000      4        10    4770055-4770074
# 2                  1   chr1       4780000      5        10    4770180-4770199
# 3                  1   chr1       4780000      6        10    4770867-4770886
# 4                  1   chr1       4780000      7        10    4773435-4773454
# ...              ...    ...           ...    ...       ...                ...
# 7501            4472  chr19      59390000  26376        10  59388426-59388445
# 7502            4472  chr19      59390000  26377        10  59388676-59388695
# 7503            4472  chr19      59390000  26378        10  59389390-59389409
# 7504            4473  chr19      59780000  26381         3  59770157-59770176
# 7505            4473  chr19      59780000  26382         3  59770474-59770493
#
#       boundary_start strand     start       end
# 0            4400000      -   4403267   4403286
# 1            4770000      +   4770055   4770074
# 2            4770000      -   4770180   4770199
# 3            4770000      +   4770867   4770886
# 4            4770000      +   4773435   4773454
# ...              ...    ...       ...       ...
# 7501        59380000      +  59388426  59388445
# 7502        59380000      -  59388676  59388695
# 7503        59380000      +  59389390  59389409
# 7504        59770000      -  59770157  59770176
# 7505        59770000      +  59770474  59770493
#
# [7506 rows x 10 columns]

# %%
nr_targets = 6
nr_sites = len(df)
nr_backgrounds = 10

# %%
seq_id = []

for seq_index in range(nr_sites):
    seq_id.append(seq_index)

df["seq_id"] = seq_id

# %%
df
# Out:
#       boundary_index  chrom  boundary_end  index  num_ctcf               span  \
# 0                  0   chr1       4410000      0         2    4403267-4403286
# 1                  1   chr1       4780000      4        10    4770055-4770074
# 2                  1   chr1       4780000      5        10    4770180-4770199
# 3                  1   chr1       4780000      6        10    4770867-4770886
# 4                  1   chr1       4780000      7        10    4773435-4773454
# ...              ...    ...           ...    ...       ...                ...
# 7501            4472  chr19      59390000  26376        10  59388426-59388445
# 7502            4472  chr19      59390000  26377        10  59388676-59388695
# 7503            4472  chr19      59390000  26378        10  59389390-59389409
# 7504            4473  chr19      59780000  26381         3  59770157-59770176
# 7505            4473  chr19      59780000  26382         3  59770474-59770493
#
#       boundary_start strand     start       end  seq_id
# 0            4400000      -   4403267   4403286       0
# 1            4770000      +   4770055   4770074       1
# 2            4770000      -   4770180   4770199       2
# 3            4770000      +   4770867   4770886       3
# 4            4770000      +   4773435   4773454       4
# ...              ...    ...       ...       ...     ...
# 7501        59380000      +  59388426  59388445    7501
# 7502        59380000      -  59388676  59388695    7502
# 7503        59380000      +  59389390  59389409    7503
# 7504        59770000      -  59770157  59770176    7504
# 7505        59770000      +  59770474  59770493    7505
#
# [7506 rows x 11 columns]

# %% [markdown]
# ## adding bg_index and experiment ID

# %%
df = add_background(
        df, [bg_index for bg_index in range(nr_backgrounds)] 
    )

# %%
exp_id = [i for i in range(nr_sites * nr_backgrounds)]
df["exp_id"] = exp_id

# %%
df
# Out:
#        boundary_index  chrom  boundary_end  index  num_ctcf  \
# 0                   0   chr1       4410000      0         2
# 1                   1   chr1       4780000      4        10
# 2                   1   chr1       4780000      5        10
# 3                   1   chr1       4780000      6        10
# 4                   1   chr1       4780000      7        10
# ...               ...    ...           ...    ...       ...
# 75055            4472  chr19      59390000  26376        10
# 75056            4472  chr19      59390000  26377        10
# 75057            4472  chr19      59390000  26378        10
# 75058            4473  chr19      59780000  26381         3
# 75059            4473  chr19      59780000  26382         3
#
#                     span  boundary_start strand     start       end  seq_id  \
# 0        4403267-4403286         4400000      -   4403267   4403286       0
# 1        4770055-4770074         4770000      +   4770055   4770074       1
# 2        4770180-4770199         4770000      -   4770180   4770199       2
# 3        4770867-4770886         4770000      +   4770867   4770886       3
# 4        4773435-4773454         4770000      +   4773435   4773454       4
# ...                  ...             ...    ...       ...       ...     ...
# 75055  59388426-59388445        59380000      +  59388426  59388445    7501
# 75056  59388676-59388695        59380000      -  59388676  59388695    7502
# 75057  59389390-59389409        59380000      +  59389390  59389409    7503
# 75058  59770157-59770176        59770000      -  59770157  59770176    7504
# 75059  59770474-59770493        59770000      +  59770474  59770493    7505
#
#        background_index  exp_id
# 0                     0       0
# 1                     0       1
# 2                     0       2
# 3                     0       3
# 4                     0       4
# ...                 ...     ...
# 75055                 9   75055
# 75056                 9   75056
# 75057                 9   75057
# 75058                 9   75058
# 75059                 9   75059
#
# [75060 rows x 13 columns]

# %% [markdown]
# ## for boundary experiment

# %%
orientation = ["<>"]

# %%
boundary_df = add_orientation(df, orientation_strings=orientation, all_permutations=False)

# %%
# adding 20bp flanks
flank = 20
spacing_list = [70]

# %%
boundary_df = add_const_flank_and_diff_spacer(boundary_df, flank, spacing_list)

# %%
boundary_df
# Out:
#        boundary_index  chrom  boundary_end  index  num_ctcf  \
# 0                   0   chr1       4410000      0         2
# 1                   1   chr1       4780000      4        10
# 2                   1   chr1       4780000      5        10
# 3                   1   chr1       4780000      6        10
# 4                   1   chr1       4780000      7        10
# ...               ...    ...           ...    ...       ...
# 75055            4472  chr19      59390000  26376        10
# 75056            4472  chr19      59390000  26377        10
# 75057            4472  chr19      59390000  26378        10
# 75058            4473  chr19      59780000  26381         3
# 75059            4473  chr19      59780000  26382         3
#
#                     span  boundary_start strand     start       end  seq_id  \
# 0        4403267-4403286         4400000      -   4403267   4403286       0
# 1        4770055-4770074         4770000      +   4770055   4770074       1
# 2        4770180-4770199         4770000      -   4770180   4770199       2
# 3        4770867-4770886         4770000      +   4770867   4770886       3
# 4        4773435-4773454         4770000      +   4773435   4773454       4
# ...                  ...             ...    ...       ...       ...     ...
# 75055  59388426-59388445        59380000      +  59388426  59388445    7501
# 75056  59388676-59388695        59380000      -  59388676  59388695    7502
# 75057  59389390-59389409        59380000      +  59389390  59389409    7503
# 75058  59770157-59770176        59770000      -  59770157  59770176    7504
# 75059  59770474-59770493        59770000      +  59770474  59770493    7505
#
#        background_index  exp_id orientation  flank_bp  spacer_bp
# 0                     0       0          <>        20         70
# 1                     0       1          <>        20         70
# 2                     0       2          <>        20         70
# 3                     0       3          <>        20         70
# 4                     0       4          <>        20         70
# ...                 ...     ...         ...       ...        ...
# 75055                 9   75055          <>        20         70
# 75056                 9   75056          <>        20         70
# 75057                 9   75057          <>        20         70
# 75058                 9   75058          <>        20         70
# 75059                 9   75059          <>        20         70
#
# [75060 rows x 16 columns]

# %%
boundary_df.to_csv("./new_correct_all_motifs_boundary.tsv", sep = "\t", index=False)

# %% [markdown]
# ## for dot experiment

# %%
orientation = ["><"]

# %%
dot_df = add_orientation(df, orientation_strings=orientation, all_permutations=False)

# %%
# adding 20bp flanks
flank = 20
spacing_list = [199980]

# %%
dot_df = add_const_flank_and_diff_spacer(dot_df, flank, spacing_list)

# %%
dot_df
# Out:
#        boundary_index  chrom  boundary_end  index  num_ctcf  \
# 0                   0   chr1       4410000      0         2
# 1                   1   chr1       4780000      4        10
# 2                   1   chr1       4780000      5        10
# 3                   1   chr1       4780000      6        10
# 4                   1   chr1       4780000      7        10
# ...               ...    ...           ...    ...       ...
# 75055            4472  chr19      59390000  26376        10
# 75056            4472  chr19      59390000  26377        10
# 75057            4472  chr19      59390000  26378        10
# 75058            4473  chr19      59780000  26381         3
# 75059            4473  chr19      59780000  26382         3
#
#                     span  boundary_start strand     start       end  seq_id  \
# 0        4403267-4403286         4400000      -   4403267   4403286       0
# 1        4770055-4770074         4770000      +   4770055   4770074       1
# 2        4770180-4770199         4770000      -   4770180   4770199       2
# 3        4770867-4770886         4770000      +   4770867   4770886       3
# 4        4773435-4773454         4770000      +   4773435   4773454       4
# ...                  ...             ...    ...       ...       ...     ...
# 75055  59388426-59388445        59380000      +  59388426  59388445    7501
# 75056  59388676-59388695        59380000      -  59388676  59388695    7502
# 75057  59389390-59389409        59380000      +  59389390  59389409    7503
# 75058  59770157-59770176        59770000      -  59770157  59770176    7504
# 75059  59770474-59770493        59770000      +  59770474  59770493    7505
#
#        background_index  exp_id orientation  flank_bp  spacer_bp
# 0                     0       0          ><        20     199980
# 1                     0       1          ><        20     199980
# 2                     0       2          ><        20     199980
# 3                     0       3          ><        20     199980
# 4                     0       4          ><        20     199980
# ...                 ...     ...         ...       ...        ...
# 75055                 9   75055          ><        20     199980
# 75056                 9   75056          ><        20     199980
# 75057                 9   75057          ><        20     199980
# 75058                 9   75058          ><        20     199980
# 75059                 9   75059          ><        20     199980
#
# [75060 rows x 16 columns]

# %%
dot_df.to_csv("./new_correct_all_motifs_dot.tsv", sep = "\t", index=False)
